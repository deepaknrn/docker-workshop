# %%
# !wget https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Out:
# --2026-01-25 11:18:39--  https://s3.amazonaws.com/nyc-tlc/misc/taxi+_zone_lookup.csv
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 54.231.236.168, 16.15.177.147, 16.15.218.77, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|54.231.236.168|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2026-01-25 11:18:40 ERROR 403: Forbidden.

# %%
"""Since the above link is not working , directly take the file from the link"""
"""http://www1.nyc.gov/site/tlc/about/tlc-trip-record-data.page"""
"""file_name=Taxi Zone Lookup Table (CSV)"

# %%
import pandas as pd
df_zones=pd.read_csv('taxi_zone_lookup.csv')
df_zones.head()
# Out:
#    LocationID        Borough                     Zone service_zone
# 0           1            EWR           Newark Airport          EWR
# 1           2         Queens              Jamaica Bay    Boro Zone
# 2           3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3           4      Manhattan            Alphabet City  Yellow Zone
# 4           5  Staten Island            Arden Heights    Boro Zone
